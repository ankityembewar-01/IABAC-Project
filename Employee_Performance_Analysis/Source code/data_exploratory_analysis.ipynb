# %%
# Below code is for getting figure in center alignment
from IPython.core.display import HTML
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}

</style>
""")
# Out:
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
#
# </style>

# %% [markdown]
# <font color='green'><h1>Basic Imports</h1></font>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# To avoid warinings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <font color='green'><h1>Reading data</h1></font>

# %%
# Reading data
df = pd.read_excel('INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.xls',index_col=0)
print(f"\033[32mDimension of data : {df.shape}")
df.head(3)
# Out:
# Dimension of data : (1200, 27)
#            Age Gender EducationBackground MaritalStatus EmpDepartment  \
# EmpNumber
# E1001000    32   Male           Marketing        Single         Sales
# E1001006    47   Male           Marketing        Single         Sales
# E1001007    40   Male       Life Sciences       Married         Sales
#
#                 EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# EmpNumber
# E1001000   Sales Executive           Travel_Rarely                10
# E1001006   Sales Executive           Travel_Rarely                14
# E1001007   Sales Executive       Travel_Frequently                 5
#
#            EmpEducationLevel  EmpEnvironmentSatisfaction  ...  \
# EmpNumber                                                 ...
# E1001000                   3                           4  ...
# E1001006                   4                           4  ...
# E1001007                   4                           4  ...
#
# ...

# %% [markdown]
# <font color='green'><h1>Information about data</h1></font>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1200 entries, E1001000 to E100998
# Data columns (total 27 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Age                           1200 non-null   int64
#  1   Gender                        1200 non-null   object
#  2   EducationBackground           1200 non-null   object
#  3   MaritalStatus                 1200 non-null   object
#  4   EmpDepartment                 1200 non-null   object
#  5   EmpJobRole                    1200 non-null   object
#  6   BusinessTravelFrequency       1200 non-null   object
#  7   DistanceFromHome              1200 non-null   int64
#  8   EmpEducationLevel             1200 non-null   int64
#  9   EmpEnvironmentSatisfaction    1200 non-null   int64
#  10  EmpHourlyRate                 1200 non-null   int64
#  11  EmpJobInvolvement             1200 non-null   int64
# ...

# %% [markdown]
#  <font color='green'><h1>Analyze Features by describing data</h1></font>

# %%
print(f"\033[32m{df.columns}")# To find the features present in the data set
# Out:
# Index(['Age', 'Gender', 'EducationBackground', 'MaritalStatus',
#        'EmpDepartment', 'EmpJobRole', 'BusinessTravelFrequency',
#        'DistanceFromHome', 'EmpEducationLevel', 'EmpEnvironmentSatisfaction',
#        'EmpHourlyRate', 'EmpJobInvolvement', 'EmpJobLevel',
#        'EmpJobSatisfaction', 'NumCompaniesWorked', 'OverTime',
#        'EmpLastSalaryHikePercent', 'EmpRelationshipSatisfaction',
#        'TotalWorkExperienceInYears', 'TrainingTimesLastYear',
#        'EmpWorkLifeBalance', 'ExperienceYearsAtThisCompany',
#        'ExperienceYearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Attrition', 'PerformanceRating'],
#       dtype='object')

# %% [markdown]
# <font color='green'><h1>Statistical Info about data</h1></font>

# %%
df.describe()
# Out:
#                Age  DistanceFromHome  EmpEducationLevel  \
# count  1200.000000       1200.000000         1200.00000
# mean     36.918333          9.165833            2.89250
# std       9.087289          8.176636            1.04412
# min      18.000000          1.000000            1.00000
# 25%      30.000000          2.000000            2.00000
# 50%      36.000000          7.000000            3.00000
# 75%      43.000000         14.000000            4.00000
# max      60.000000         29.000000            5.00000
#
#        EmpEnvironmentSatisfaction  EmpHourlyRate  EmpJobInvolvement  \
# count                 1200.000000    1200.000000        1200.000000
# mean                     2.715833      65.981667           2.731667
# std                      1.090599      20.211302           0.707164
# min                      1.000000      30.000000           1.000000
# 25%                      2.000000      48.000000           2.000000
# ...

# %% [markdown]
# <font color='green'><h2>Check for cardinality</h2></font><br>
# <font color='green'>This is all about how many distinct values are in a column.</font>

# %%
df.describe(exclude='number')
# Out:
#        Gender EducationBackground MaritalStatus EmpDepartment  \
# count    1200                1200          1200          1200
# unique      2                   6             3             6
# top      Male       Life Sciences       Married         Sales
# freq      725                 492           548           373
#
#              EmpJobRole BusinessTravelFrequency OverTime Attrition
# count              1200                    1200     1200      1200
# unique               19                       3        2         2
# top     Sales Executive           Travel_Rarely       No        No
# freq                270                     846      847      1022

# %% [markdown]
# <font color='green'><h2>Checking for duplicates</h2></font>

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <font color='green'><h1>Numerical Features</h1></font>

# %%
num_data = df[['Age','DistanceFromHome','EmpHourlyRate','NumCompaniesWorked','EmpLastSalaryHikePercent', 
               'TotalWorkExperienceInYears','TrainingTimesLastYear','ExperienceYearsAtThisCompany',
               'ExperienceYearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager']]

num_data.columns = ['Age','Distance From Home','Employee Hourly Rate','Number Companies Worked',
                    'Employee Last Salary Hike Percent', 'Total Work Experience In Years','Training Times Last Year',
                    'Experience Years At This Company','Experience Years In Current Role','Years Since Last Promotion',
                    'Years With Current Manager']

# %% [markdown]
# <font color='green'><h1>Check for Normal Distribution</h1></font>

# %%
sns.set(rc={"font.size":15,"axes.titlesize":15,"axes.labelsize":22,"xtick.labelsize":15,"ytick.labelsize":15,
            "legend.fontsize":12,'axes.grid' : False,'axes.facecolor': 'white'})

fig = plt.figure(figsize=(35,25))
fig.suptitle("Statistical Analysis of Numerical type data", fontsize=35,fontweight="bold",color="brown")
for index,col in enumerate(num_data):
    plt.subplot(4,4,index+1)
    sns.distplot(num_data.loc[:,col].dropna(),kde=True,bins=20,color="g")
    plt.xlabel(f"\n{col}",fontweight="bold",color="brown")
    plt.ylabel("Density\n",fontweight="bold",color="brown")
fig.tight_layout(pad=4.0)
fig.subplots_adjust(top=0.93)

# %%
# Defining a function for checking  skewness
from scipy.stats import skew, kurtosis
def skewedness(data):
    skewed=[]
    for col in data:
        sk=data[col].skew()
        if(sk>=1.96 or sk<=-1.96):
            skewed.append(col)
    return skewed


print(f"\033[32mSkewed Column name : {skewedness(num_data)}")
print('\033[32mRange of skewness & kurtosis, S < |1.96|')
# Checking Kurtosis
print('\033[32mSkewness for YearsSinceLastPromotion:',skew(df.YearsSinceLastPromotion))
print('\033[32mKurtosis for YearsSinceLastPromotion:',kurtosis(df.YearsSinceLastPromotion))
# Out:
# Skewed Column name : ['Years Since Last Promotion']
# Range of skewness & kurtosis, S < |1.96|
# Skewness for YearsSinceLastPromotion: 1.9724620367914252
# Kurtosis for YearsSinceLastPromotion: 3.5193552691799805

# %% [markdown]
# <font color='green'><h1>Operation on Skewed Data</h1></font>

# %%
# Set figure size for the notebook
sns.set(rc={"font.size":15,"axes.titlesize":17,"axes.labelsize":15,"xtick.labelsize":15,"ytick.labelsize":15,
            "legend.fontsize":12})
plt.figure(figsize=(10,6))
sns.distplot(num_data['Years Since Last Promotion'],color="g")
plt.xlabel("\nYears Since Last Promotion",color="brown")
plt.ylabel("Density\n",color="brown")
plt.title("Positive Skewed Data\n",color="brown",fontweight="bold",fontsize="18")
plt.show()

# %% [markdown]
# <font color='green'><h3>Square Root Transformation</h3></font><br>
# <font color='green'>Square root transformation</b> is one of the many types of standard transformations.This transformation is used for count data (data that follow a Poisson distribution) or small whole numbers. Each data point is replaced by its square root. Negative data is converted to positive by adding a constant, and then transformed.</font>

# %%
# applying square root to the skewed column
num_data['Years Since Last Promotion'] = np.sqrt(num_data['Years Since Last Promotion'])

# %% [markdown]
# <font color='green'><h3>After Operation on Skewed Data</h3></font>

# %%
print(f"\033[32m{num_data['Years Since Last Promotion'].skew()}")
# Out:
# 0.7350121906940618

# %%
# Set figure size for the notebook
sns.set(rc={"font.size":15,"axes.titlesize":17,"axes.labelsize":15,"xtick.labelsize":15,"ytick.labelsize":15,
            "legend.fontsize":12})
plt.figure(figsize=(10,6))
sns.distplot(num_data['Years Since Last Promotion'],color="g")
plt.xlabel("\nYears Since Last Promotion",color="brown")
plt.ylabel("Density\n",color="brown")
plt.title("After Operation on Skewed Data\n",color="brown",fontweight="bold",fontsize=18)
plt.show()

# %% [markdown]
# <font color="green"><h3>Recheck for skewed data</h3></font>

# %%
# checking for skewed columns
from scipy.stats import skew, kurtosis
def skewedness(data):
    skewed=[]
    for col in data:
        sk=data[col].skew()
        if(sk>=1.96 or sk<=-1.96):
            skewed.append(col)
    return skewed

print(f"\033[32m{skewedness(num_data)}")
# Out:
# []

# %% [markdown]
# <font color="green"><h2>Data Analysis</h2></font>

# %%
#!pip install sweetviz
import sweetviz as sv
my_report = sv.analyze(df)
my_report.show_notebook()
# Out:
# ...
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.4.1 | (c) JS Foundation and other contributors | jquery.org/license */
# ...

# %% [markdown]
# <font color="green"><h2>Ordinal features</h2></font>

# %%
# Defing ordinal features
ord_data = df[['EmpEducationLevel','EmpEnvironmentSatisfaction','EmpJobInvolvement','EmpJobLevel','EmpJobSatisfaction',
'EmpRelationshipSatisfaction','EmpWorkLifeBalance']]

ord_data.columns = ['Employee Education Level','Employee Environment Satisfaction','Employee Job Involvement','Employee Job Level','Employee Job Satisfaction',
'Employee Relationship Satisfaction','Employee Work LifeBalance']
# figure size for the notebook
fig = plt.figure(figsize=(25,15))
fig.suptitle("Statistical Analysis of Ordinal type data", fontsize=30,fontweight="bold",color="brown")
# Creating loop for ploting ordinal features
for index,cols in enumerate(ord_data):
    plt.subplot(3,3,index+1)
    sns.distplot(ord_data.loc[:,cols],color="g")
    plt.xlabel(f'\n{cols}',color="brown",fontsize=19,fontweight="bold")
    plt.ylabel(f'Density\n',color="brown",fontsize=19,fontweight="bold")
plt.tight_layout(pad=2)
fig.subplots_adjust(top=0.92)

# %% [markdown]
# <font color="green"><h2>Categorical features</h2></font>

# %%
# storing object type data in obj_data variable
obj_data = df.select_dtypes(include="object")
print(f"\033[32m{obj_data.columns}")
# Out:
# Index(['Gender', 'EducationBackground', 'MaritalStatus', 'EmpDepartment',
#        'EmpJobRole', 'BusinessTravelFrequency', 'OverTime', 'Attrition'],
#       dtype='object')

# %%
#changes the column name
obj_data.columns = ['Gender', 'Education Background', 'Marital Status', 'Employees Department',
       'Employees Job Role', 'Business Travel Frequency', 'Over Time', 'Attrition']
obj_data
# Out:
#            Gender Education Background Marital Status Employees Department  \
# EmpNumber
# E1001000     Male            Marketing         Single                Sales
# E1001006     Male            Marketing         Single                Sales
# E1001007     Male        Life Sciences        Married                Sales
# E1001009     Male      Human Resources       Divorced      Human Resources
# E1001010     Male            Marketing         Single                Sales
# ...           ...                  ...            ...                  ...
# E100992    Female              Medical       Divorced                Sales
# E100993      Male        Life Sciences         Single          Development
# E100994      Male              Medical        Married          Development
# E100995    Female              Medical         Single         Data Science
# E100998    Female        Life Sciences         Single                Sales
#
# ...

# %% [markdown]
# <font color="green"><h2>Creating final dataframe</h2></font>

# %%
# combining numerical, ordinal & categorial features
final_df = pd.concat([num_data,ord_data,obj_data,df['PerformanceRating']], axis=1)
final_df
# Out:
#            Age  Distance From Home  Employee Hourly Rate  \
# EmpNumber
# E1001000    32                  10                    55
# E1001006    47                  14                    42
# E1001007    40                   5                    48
# E1001009    41                  10                    73
# E1001010    60                  16                    84
# ...        ...                 ...                   ...
# E100992     27                   3                    71
# E100993     37                  10                    80
# E100994     50                  28                    74
# E100995     34                   9                    46
# E100998     24                   3                    65
#
#            Number Companies Worked  Employee Last Salary Hike Percent  \
# EmpNumber
# E1001000                         1                                 12
# E1001006                         2                                 12
# ...

# %%
print(f"\033[32m{obj_data.columns}")
# Out:
# Index(['Gender', 'Education Background', 'Marital Status',
#        'Employees Department', 'Employees Job Role',
#        'Business Travel Frequency', 'Over Time', 'Attrition'],
#       dtype='object')

# %% [markdown]
# <font color="green"><h3>Label Encoder </h3></font>

# %%
# Converting Labeled data to Numerical data using label Encoder
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
final_df[['Gender', 'Education Background', 'Marital Status','Employees Department', 'Employees Job Role',
       'Business Travel Frequency', 'Over Time', 'Attrition']] = final_df[['Gender', 'Education Background', 
       'Marital Status','Employees Department', 'Employees Job Role','Business Travel Frequency', 'Over Time', 
                                                                           'Attrition']].apply(label.fit_transform)

# %% [markdown]
# <font color="green"><h2>Defining features & target variables</h2></font>

# %%
# defing Independent variables as X
X = final_df.iloc[:,:-1]
# Defing Target variable or dependent variable
y = final_df.iloc[:,-1]

# %% [markdown]
# <font color="green"><h1>Correlation with target variable</h1><font><br>
# * <font color="green">Correlation is a statistical measure that indicates the extent to which two or more variables fluctuate in relation to each other. A positive correlation indicates the extent to which those variables increase or decrease in parallel; a negative correlation indicates the extent to which one variable increases as the other decreases.</font><br><br>
# * <font color="green"><i><b>Note : </b> Here, target variable is <b>Performance Rating</b></i></font>

# %%
plt.style.use('ggplot')
ax = X.corrwith(y).plot(kind='barh', grid=True, figsize=(12,12),color='indigo')
plt.title("Correlation with target variable\n", size=20,color="brown")
plt.xticks(size=15)
plt.yticks(size=15)
ax.xaxis.label.set_color('purple')
ax.yaxis.label.set_color('brown')
plt.show()

# %% [markdown]
# <font color="green">There are <b>eight</b> variables are <b>positively</b> correlated with performance rating( Target variable)<br>
# 1. Employee Environment Satisfaction<br>
# 2. Employee Last Salary Hike Percent<br>
# 3. Employee Work Life Balance
# 4. Over Time
# 5. Marital Status
# 6. Number Companies Worked
# 7. Employees Education Level
# 8. Education Background</font>

# %% [markdown]
# <font color="green"><h1>Is given given dataset balanced or imbalanced?</h1></font>

# %%
print(f"\033[32m{y.value_counts()}")
# Out:
# 3    874
# 2    194
# 4    132
# Name: PerformanceRating, dtype: int64

# %% [markdown]
# <font color="green">From above output, we can say that data is <b>imbalanced</b></font>

# %% [markdown]
# <font color="green"><h2>Handling Imbalanced data</h2></font><br>
#
# <font color="green"><h3>Converting Imbalance data into balanced data</h3><br>
# * Balancing data with SMOTE Technique gives more number of NaN values.
# * so, we use RandomOverSampler Technique to balance the data</font>

# %%
# Imports
from imblearn.over_sampling import RandomOverSampler,SMOTENC,SMOTE
# Intilizing the model
oversampling = RandomOverSampler()
X_over, y_over = oversampling.fit_sample(X,y)
X_over = pd.DataFrame(X_over)
X_over.columns = ['Age', 'Distance From Home', 'Employee Hourly Rate',
       'Number Companies Worked', 'Employee Last Salary Hike Percent',
       'Total Work Experience In Years', 'Training Times Last Year',
       'Experience Years At This Company', 'Experience Years In Current Role',
       'Years Since Last Promotion', 'Years With Current Manager',
       'Employee Education Level', 'Employee Environment Satisfaction',
       'Employee Job Involvement', 'Employee Job Level',
       'Employee Job Satisfaction', 'Employee Relationship Satisfaction',
       'Employee Work LifeBalance', 'Gender', 'Education Background',
       'Marital Status', 'Employees Department', 'Employees Job Role',
       'Business Travel Frequency', 'Over Time', 'Attrition']
print(f"\033[32m{y_over.value_counts()}")
# Out:
# 3    874
# 4    874
# 2    874
# Name: PerformanceRating, dtype: int64

# %% [markdown]
# <font color="green"> Now from above output, we can say that data is balanced</font>

# %% [markdown]
# <font color="green"><h1>Feature Selection</h1></font>

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

bestfeatures = SelectKBest(score_func=chi2,k=15)
fit = bestfeatures.fit(X_over,y_over)

dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X_over.columns)

featurescores = pd.concat([dfcolumns,dfscores],axis=1)
featurescores.columns = ['feature_names','Scores']

print(f"\033[32m{featurescores.nlargest(5,'Scores')}")
# Out:
#                         feature_names       Scores
# 4   Employee Last Salary Hike Percent  1206.615406
# 7    Experience Years At This Company   566.491161
# 12  Employee Environment Satisfaction   489.245471
# 8    Experience Years In Current Role   359.262544
# 9          Years Since Last Promotion   325.600421

# %% [markdown]
# <font color="green">From Feature Selection Technique. We get <b> Top 5 </b> features which effect the <b> Target variable</b> Performance Rating<br>
# * EmpLastSalaryHikePercent
# * YearsSinceLastPromotion
# * ExperienceYearsAtThisCompany
# * EmpEnvironmentSatisfaction
# * ExperienceYearsInCurrentRole </font>
